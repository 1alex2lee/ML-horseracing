# %%
import numpy as np
import tensorflow as tf
import os
import pandas as pd

# %%
def extract_columns (df, columns):
    new_df = pd.DataFrame()
    for c in columns:
        if c in df.columns:
            new_df[c] = df[c]
        else:
            new_df[c] = np.nan
    return new_df

# %%
in_path = os.path.join("data","2_cleaned",'horses')
out_path = os.path.join("data","3_extracted")

for file_name in [f for f in os.listdir(in_path) if not f.startswith(".")]:

    # try:
    #     df = pd.read_csv(os.path.join(out_path, file_name), index_col=0)
    #     if 'jockey_age' in df.columns:
    #         continue
    # except:
    #     pass

    horse_df = pd.read_csv(os.path.join(in_path, file_name), index_col=0)
    if 'horse_finish_time' not in horse_df.columns:
        continue
    for c in horse_df.columns:
        horse_df[c] = horse_df[c].apply(lambda x: str(x).lower())
    horse_df['horse_name'] = file_name.split('(')[0].strip()
    horse_df['finish_time'] = horse_df['horse_finish_time']
    horse_df['race_date'] = pd.to_datetime(horse_df['race_date'], format='%Y/%m/%d', errors='coerce')
    horse_df['race_index'] = horse_df['race_date'].apply(lambda x: x.strftime('%Y_')) + pd.to_numeric(horse_df['Race Index']).astype(int).astype(str)
    horse_df.drop_duplicates('race_date', inplace=True)
    horse_df = horse_df[horse_df['horse_finish_time'] != '--']
    horse_df.reset_index(drop=True, inplace=True)
    if 'Import Date' in horse_df.columns:
        horse_df['Import Date'] = pd.to_datetime(horse_df['Import Date'], format='%d/%m/%Y', errors='coerce')
        horse_df['days_since_import'] = (horse_df['race_date'] - horse_df['Import Date']).apply(lambda x: x.days)
    else:
        earliest_race_date = horse_df['race_date'].min()
        horse_df['days_since_import'] = (horse_df['race_date'] - earliest_race_date).apply(lambda x: x.days + 177)
    horse_df['horse_gear'] = (horse_df['Gear'] != '--').astype(int)
    horse_df['total_stakes'] = horse_df['Total Stakes*'].apply(lambda x: x.replace('$','').replace(',',''))

    jockey_age = []
    jockey_nationality = []
    jockey_wins = []
    jockey_rides = []
    jockey_stakes = []
    jockey_same_race_wins = []

    for idx, row in horse_df.iterrows():
        jockey_file_path = os.path.join('data','1_scrape','jockeys',f'{row["Jockey"]}.csv')
        if not os.path.exists(jockey_file_path):
            jockey_age.append(np.nan)
            jockey_nationality.append(np.nan)
            jockey_wins.append(np.nan)
            jockey_rides.append(np.nan)
            jockey_stakes.append(np.nan)
            jockey_same_race_wins.append(np.nan)
            continue
        jockey_df = pd.read_csv(jockey_file_path, index_col=0)
        try:
            jockey_age.append(int(jockey_df['jockey_age'].unique()[0]) - (2023 - int(row['race_date'].year)))
        except:
            jockey_age.append(np.nan)
        jockey_nationality.append(jockey_df['nationality'].unique()[0])
        jockey_wins.append(jockey_df['no. of wins'].unique()[0])
        jockey_rides.append(jockey_df['total rides'].unique()[0])
        jockey_stakes.append(str(jockey_df['stakes won'].unique()[0]).replace('$','').replace(',','').strip())

        race_distance = str(row["race_distance"]).replace('.0','')
        if 'sha tin' in row["race_location"]:
            try:
                jockey_same_race_wins.append(jockey_df[f'{row["race_surface"]}_{race_distance}_win'].unique()[0])
            except:
                jockey_same_race_wins.append(jockey_df[f'sha tin_all weather_{race_distance}_win'].unique()[0])
        else:
            jockey_same_race_wins.append(jockey_df[f'{row["race_location"].replace("ch","conghua")}_{race_distance}_win'].unique()[0])

    horse_df['jockey_age'] = jockey_age
    horse_df['jockey_nationality'] = jockey_nationality
    horse_df['jockey_wins'] = jockey_wins
    horse_df['jockey_rides'] = jockey_rides
    horse_df['jockey_stakes'] = jockey_stakes
    horse_df['jockey_same_race_wins'] = jockey_same_race_wins

    df = extract_columns(horse_df, ['race_index','race_date','total_stakes','horse_name','horse_weight','horse_handicap','horse_odds','horse_rating','horse_import_type','horse_sex','horse_colour',
                'horse_age','horse_origin','horse_gear','days_since_import',
                'draw',
                'jockey_age','jockey_nationality','jockey_wins','jockey_rides','jockey_stakes','jockey_same_race_wins',
                'race_location','race_class','race_going','race_distance','race_surface','race_course',
                'finish_time','place'])

    df.to_csv(os.path.join(out_path, file_name))
    print(file_name, 'saved')
# Out:
# strongest boy(h027).csv saved
# le plus vite(g242).csv saved
# spicy grill(d159).csv saved
# ever blessing(h187).csv saved
# dorado fig(g332).csv saved
# coming patch(g222).csv saved
# super wealthy(d108).csv saved
# to infinity(g277).csv saved
# general winner(e376).csv saved
# nearly fine(e430).csv saved
# podium(h173).csv saved
# gift of lifeline(c172).csv saved
# winwin thirtythree(c110).csv saved
# horse of good luck(h160).csv saved
# ka ying glorious(h026).csv saved
# capital delight(h262).csv saved
# touch faith(e153).csv saved
# nordic star(g433).csv saved
# mark the moment(h088).csv saved
# flagship warrior(g452).csv saved
# silver fig(b025).csv saved
# super wise dragon(g475).csv saved
# goal oriented(g254).csv saved
# super eagle(g408).csv saved
# amazing victory(g123).csv saved
# young explorer(g084).csv saved
# hei wongchoy(g187).csv saved
# sky forever(e414).csv saved
# one step ahead(c242).csv saved
# call me teddy(g233).csv saved
# our class act(e303).csv saved
# beauty crescent(h334).csv saved
# vanquisher(h131).csv saved
# family folks(d505).csv saved
# sterling wongchoy(h273).csv saved
# little fairy(h206).csv saved
# rainbow light(e051).csv saved
# ensured(g136).csv saved
# yes we can(c307).csv saved
# jolly ruler(e346).csv saved
# durham star(e082).csv saved
# out to win(h825).csv saved
# nordic sky(e412).csv saved
# pins prince(g013).csv saved
# stoltz(g147).csv saved
# holy power(h039).csv saved
# danon scorpion(h807).csv saved
# trillion win(e240).csv saved
# cervin(h253).csv saved
# m unicorn(g466).csv saved
# our lucky glory(g292).csv saved
# more than enough(d372).csv saved
# forever folks(g463).csv saved
# jade phoenix(d179).csv saved
# glenealy generals(b475).csv saved
# happy hunk(h101).csv saved
# looking great(e053).csv saved
# pride of dragon(e283).csv saved
# flying shelby(h316).csv saved
# forest gold(g359).csv saved
# marado(e245).csv saved
# togepi(g458).csv saved
# mulan(h145).csv saved
# regency poet(d010).csv saved
# happy forever(g118).csv saved
# galaxy witness(g110).csv saved
# entrusted(d381).csv saved
# the good deal(g025).csv saved
# ho ho star(h291).csv saved
# dream winner(h308).csv saved
# super legends(h364).csv saved
# sparky star(c416).csv saved
# loyal baby(e130).csv saved
# my ecstatic(e004).csv saved
# general trump(b394).csv saved
# smoothies(d233).csv saved
# june planet(h080).csv saved
# beauty nova(g232).csv saved
# cable speed(d459).csv saved
# success allstars(d065).csv saved
# see u again(g247).csv saved
# high percentage(g413).csv saved
# hercules(c476).csv saved
# multiwin(h023).csv saved
# singapore spirit(g047).csv saved
# coolceleb(c030).csv saved
# gold marquis(g111).csv saved
# modest gentleman(g352).csv saved
# team spirit(b230).csv saved
# kowloon east star(e158).csv saved
# seaweed fortune(c440).csv saved
# galvanic(h147).csv saved
# california vanes(g160).csv saved
# give way please(e035).csv saved
# golden luck(h159).csv saved
# tamra blitz(g237).csv saved
# packing succeeder(h038).csv saved
# the equalizer(g445).csv saved
# many wins(e468).csv saved
# ready player one(g143).csv saved
# superb capitalist(h092).csv saved
# be ready(d024).csv saved
# chill way(g375).csv saved
# regency star(e399).csv saved
# power koepp(e301).csv saved
# prince alex(g307).csv saved
# buddies(c019).csv saved
# tung haye haye(g105).csv saved
# speedy chariot(h193).csv saved
# crystal powerful(h068).csv saved
# nunchuks(c357).csv saved
# blaze warrior(d450).csv saved
# always beautiful(g361).csv saved
# simple doctrine(e180).csv saved
# mister arm(d491).csv saved
# lucky victor(c514).csv saved
# goko win(h069).csv saved
# mighty stride(g346).csv saved
# flying mojito(g412).csv saved
# booming well(e252).csv saved
# happy soul(g249).csv saved
# tycoon jewellery(e473).csv saved
# lucky gor(g217).csv saved
# travel guide(h182).csv saved
# sword point(g448).csv saved
# flash famous(b162).csv saved
# sunny delight(e339).csv saved
# born the same day(e458).csv saved
# delago patrol(h236).csv saved
# island bright(h363).csv saved
# delightful laos(d321).csv saved
# lucky with you(e356).csv saved
# war weapon(e257).csv saved
# buddy spirit(g048).csv saved
# po on way(h201).csv saved
# art lite(h249).csv saved
# dashing triumph(g341).csv saved
# super joy(g251).csv saved
# miracles(g083).csv saved
# excellent fighter(g343).csv saved
# brother pearl(h030).csv saved
# wonderful unicorn(g362).csv saved
# hang's choice(e311).csv saved
# e legend(g028).csv saved
# campione(g235).csv saved
# california rad(d147).csv saved
# ennea fortune(e443).csv saved
# yoo yoo knight(h053).csv saved
# xponential(d049).csv saved
# holi moli(g327).csv saved
# powerful wings(g225).csv saved
# handsome veggie(g007).csv saved
# royal campbell(d477).csv saved
# spartan missile(e420).csv saved
# run the table(d229).csv saved
# good view glory(h154).csv saved
# circuit spiritanto(e483).csv saved
# excellent daddy(e321).csv saved
# dublin star(c436).csv saved
# owners' praise(h047).csv saved
# super fortune(g065).csv saved
# run des run(e179).csv saved
# ha lee charm(g321).csv saved
# mugen(h338).csv saved
# courier magic(h290).csv saved
# over the moon(g162).csv saved
# sonic boom(h144).csv saved
# tiger legend(h222).csv saved
# fun n glory(g003).csv saved
# win win charity(g248).csv saved
# prestige moochi(h314).csv saved
# encore(e450).csv saved
# ring bells(g036).csv saved
# splendid star(g026).csv saved
# flying quest(a071).csv saved
# fifer(h826).csv saved
# noir rider(e138).csv saved
# hunky dory(e438).csv saved
# joy of spring(h383).csv saved
# cheer for south(h178).csv saved
# spontaneous(d106).csv saved
# aoraki summit(h300).csv saved
# phoenix light(g192).csv saved
# eighty light years(h170).csv saved
# holy lake(h260).csv saved
# carry the diamond(d122).csv saved
# packing treadmill(g161).csv saved
# day day rich(d231).csv saved
# sunlight power(h244).csv saved
# humble star(h125).csv saved
# lucky missile(c501).csv saved
# sunshine legendary(g214).csv saved
# wonder kit(g455).csv saved
# berlin tango(e120).csv saved
# wayfoong legend(g399).csv saved
# foxhunter way(e296).csv saved
# eight trigrams(c102).csv saved
# ping hai bravo(d123).csv saved
# smart cousin(d249).csv saved
# dragon kingdom(e211).csv saved
# quadruple double(b250).csv saved
# red elysees(a005).csv saved
# prosecco(e457).csv saved
# solar partner(e364).csv saved
# circuit mighty(g078).csv saved
# healthy happy(d435).csv saved
# toronado phantom(e300).csv saved
# river views(g212).csv saved
# telecom missile(d209).csv saved
# roaring bebe(h105).csv saved
# diamond soars(g201).csv saved
# aestheticism(h289).csv saved
# king invincible(h199).csv saved
# shenzhou twelve(g164).csv saved
# strive for glory(d186).csv saved
# not usual star(g396).csv saved
# stradale(g438).csv saved
# eternal bloom(g185).csv saved
# win marilyn(h816).csv saved
# timestorm(g109).csv saved
# mega bonus(e184).csv saved
# reliable profit(g462).csv saved
# packing present(h043).csv saved
# tourbillon prince(h122).csv saved
# call me dandy(g469).csv saved
# good luck friend(d228).csv saved
# chateau(h214).csv saved
# turin mascot(h165).csv saved
# righteous doctrine(c197).csv saved
# beauty tycoon(g329).csv saved
# diamond brilliant(b372).csv saved
# golden warsteed(g350).csv saved
# danon the kid(h811).csv saved
# tsuen wan glory(e403).csv saved
# management heart(h211).csv saved
# sea sapphire(h343).csv saved
# healthy healthy(h203).csv saved
# chrysos(h136).csv saved
# one for all(g012).csv saved
# nobody knows(g038).csv saved
# we are hero(g207).csv saved
# sunny and gold(d177).csv saved
# sturdy ruby(h207).csv saved
# running glory(g010).csv saved
# circuit elite(e487).csv saved
# golden bull(h019).csv saved
# noble steed(a326).csv saved
# wild west wing(c381).csv saved
# super ten(d362).csv saved
# run run cool(e322).csv saved
# zone d(d415).csv saved
# red hare king(h188).csv saved
# namjong sings(c480).csv saved
# hells bells(h280).csv saved
# island shine(d040).csv saved
# red elegance(h241).csv saved
# beauty turn(h074).csv saved
# pegasus hero(g188).csv saved
# exceptional nice(d367).csv saved
# kings shield(c071).csv saved
# winning method(c383).csv saved
# california cible(e431).csv saved
# life is good(h118).csv saved
# perfect peach(e488).csv saved
# leather vanguard(e491).csv saved
# noble win(h195).csv saved
# shining gem(c058).csv saved
# king tourbillon(g097).csv saved
# takingufurther(c131).csv saved
# travel golf(h063).csv saved
# handsome bo bo(b119).csv saved
# seasons wit(h223).csv saved
# star brite(g104).csv saved
# wah may luck(e086).csv saved
# jumbo legend(g266).csv saved
# rewarding together(d334).csv saved
# fearless fire(b085).csv saved
# el valiente(d124).csv saved
# viva popcorn(d307).csv saved
# united we stand(d048).csv saved
# packing monkeyking(g390).csv saved
# six best friends(g205).csv saved
# good runner(e285).csv saved
# leather master(h034).csv saved
# prime mortar(g328).csv saved
# goodmanship(e208).csv saved
# regency bo bo(a050).csv saved
# money catcher(g171).csv saved
# colourful baron(g301).csv saved
# golden link(d222).csv saved
# wine and wine(e101).csv saved
# sunny star(d273).csv saved
# brilliant pioneer(g255).csv saved
# laugh tale(g406).csv saved
# ambitious heart(v303).csv saved
# chilli baba(g339).csv saved
# perfect team(h120).csv saved
# faithful trinity(a247).csv saved
# lucky patch(d422).csv saved
# fast buck(h126).csv saved
# imperial goodness(h225).csv saved
# raging blizzard(h368).csv saved
# science patch(e442).csv saved
# nothing new(e127).csv saved
# cheerful days(d473).csv saved
# amazing ace(h359).csv saved
# colonel(d090).csv saved
# triple triple(c359).csv saved
# harmony fire(e175).csv saved
# flaming passion(e084).csv saved
# shiny two(g041).csv saved
# savvy chic(g261).csv saved
# woodfire bro(g115).csv saved
# kimberley(h329).csv saved
# diamond flare(h224).csv saved
# king eccellente(g264).csv saved
# general ace(g425).csv saved
# star club(h239).csv saved
# gracylove(d098).csv saved
# sunny baby(e166).csv saved
# lapras(h374).csv saved
# dan attack(h317).csv saved
# wind n grass(d197).csv saved
# northern beast(h233).csv saved
# trader(e287).csv saved
# bulletproof(d219).csv saved
# atomic force(g221).csv saved
# karuizawa(g293).csv saved
# spicy so smart(g203).csv saved
# happy won(g353).csv saved
# red titan(e309).csv saved
# momentum galaxy(c275).csv saved
# sixth generation(g120).csv saved
# viva a la(g282).csv saved
# champion method(h366).csv saved
# sunny boy(a379).csv saved
# fiery diamond(g022).csv saved
# super contented(h251).csv saved
# talents supremo(h133).csv saved
# california redwood(g224).csv saved
# super red dragon(c191).csv saved
# lightning warrior(g428).csv saved
# five elements(e423).csv saved
# party warrior(e368).csv saved
# flying high(e204).csv saved
# faribault(d454).csv saved
# fast serve(h240).csv saved
# jazz steed(c406).csv saved
# e brother(e266).csv saved
# sinba(h091).csv saved
# tuchel(g345).csv saved
# fortune winner(e248).csv saved
# bon's a pearla(g449).csv saved
# royal bomb(e143).csv saved
# winner method(e178).csv saved
# the best peach(h139).csv saved
# regent glory(e323).csv saved
# sure winner(d488).csv saved
# pegasus general(g189).csv saved
# joy coming(h149).csv saved
# master eight(e330).csv saved
# war of courage(c483).csv saved
# amazing one plus(d173).csv saved
# flying dragon(e360).csv saved
# lucky encounter(h274).csv saved
# easy life(g113).csv saved
# will power(d093).csv saved
# find my love(h110).csv saved
# always awesome(h245).csv saved
# take what you need(c474).csv saved
# decisive twelve(d280).csv saved
# super baby(g364).csv saved
# moon catcher(g218).csv saved
# the multiplier(e320).csv saved
# mister monte(a201).csv saved
# glorious dragon(c120).csv saved
# reach goal(g067).csv saved
# the final word(h184).csv saved
# theta hedge(e307).csv saved
# lucky fun(e013).csv saved
# simple hedge(h237).csv saved
# mach ten(g382).csv saved
# sight spirit(g018).csv saved
# fastpass(h040).csv saved
# united endeavors(g030).csv saved
# erimo(e193).csv saved
# red lion(h115).csv saved
# packing victory(e373).csv saved
# pulsar strider(g407).csv saved
# karma(g392).csv saved
# apache pass(d433).csv saved
# charity go(b478).csv saved
# columbus county(c465).csv saved
# sun of makfi(d157).csv saved
# gluck racer(e157).csv saved
# cobhfield(e406).csv saved
# nordic dragon(g467).csv saved
# painter(e375).csv saved
# atomic energy(h150).csv saved
# joy in joy(h054).csv saved
# here comes ted(c457).csv saved
# our creed(d464).csv saved
# fantastic way(e219).csv saved
# dashing success(h152).csv saved
# helene allibor(e348).csv saved
# red impact(e262).csv saved
# noble one(g278).csv saved
# president's choice(d038).csv saved
# explosive witness(b001).csv saved
# golden sixty(c238).csv saved
# stormtrouper(e100).csv saved
# nicconi county(g208).csv saved
# resistencia(g802).csv saved
# gallant valour(h323).csv saved
# highland fortune(c292).csv saved
# sergeant pepper(e432).csv saved
# naran huleg(h802).csv saved
# generous friend(g439).csv saved
# navas two(g094).csv saved
# righteous arion(h059).csv saved
# golden artie(g434).csv saved
# meaningful star(e230).csv saved
# meikei yell(h804).csv saved
# lean master(h134).csv saved
# glory bo bo(g262).csv saved
# gold tack(h106).csv saved
# darci legend(g376).csv saved
# computer patch(d139).csv saved
# bayview star(g411).csv saved
# smiling city(d113).csv saved
# goodluck goodluck(b188).csv saved
# fortune marbo(g177).csv saved
# cyber patch(h158).csv saved
# boombayah(h307).csv saved
# gem of south china(e038).csv saved
# packing famous(e381).csv saved
# happy day(g119).csv saved
# win win(b472).csv saved
# telecom fighters(d482).csv saved
# natural gold(e402).csv saved
# czarson(d394).csv saved
# s j tourbillon(g138).csv saved
# salios(g804).csv saved
# london luckystar(c368).csv saved
# all riches(g060).csv saved
# farshad(b238).csv saved
# wind speeder(e281).csv saved
# hameron(h265).csv saved
# boys party(e394).csv saved
# handsome twelve(e462).csv saved
# ai one(e139).csv saved
# e glory(h304).csv saved
# urban triumph(h200).csv saved
# equilibrium turbo(e195).csv saved
# romantic charm(h227).csv saved
# regency gem(c035).csv saved
# bear slam(c143).csv saved
# triumphant return(g320).csv saved
# broome(g814).csv saved
# travel glory(e170).csv saved
# spangle fortune(g427).csv saved
# brilliant way(g215).csv saved
# street scream(d234).csv saved
# family strength(g421).csv saved
# massive action(e445).csv saved
# majestic star(e203).csv saved
# panthalassa(h809).csv saved
# golden fairy(e448).csv saved
# happy jai jai(e069).csv saved
# jubilation(g029).csv saved
# outpacer(g342).csv saved
# big red(h299).csv saved
# melbourne hall(d118).csv saved
# vincy(b213).csv saved
# devil and gold(g443).csv saved
# red desert(c287).csv saved
# romantic warrior(e486).csv saved
# g liner(h072).csv saved
# snaffles(g299).csv saved
# telecom dragon(h322).csv saved
# california deeply(g451).csv saved
# whizz kid(e392).csv saved
# further forward(h157).csv saved
# soaring pengshan(h049).csv saved
# reward smile(h256).csv saved
# outgate(h113).csv saved
# wings of war(h162).csv saved
# crown of star(h179).csv saved
# panda legend(h002).csv saved
# multidarling(h148).csv saved
# chicken dance(c099).csv saved
# luck star(e474).csv saved
# brilliant eight(g280).csv saved
# captain hurricane(g391).csv saved
# mighty valor(c338).csv saved
# la city blanche(g371).csv saved
# shining red(e278).csv saved
# star of yuen long(c303).csv saved
# flying gallop(g472).csv saved
# o'liner(h264).csv saved
# storm legend(g139).csv saved
# special hedge(h354).csv saved
# enjoying(d066).csv saved
# speedy fortune(h097).csv saved
# massive talent(h282).csv saved
# embarked(e407).csv saved
# leading fortune(c441).csv saved
# lost child(g461).csv saved
# joyful champion(g072).csv saved
# telecom cheetah(d405).csv saved
# pragmatism(g234).csv saved
# cheery(g021).csv saved
# lean hero(g402).csv saved
# high rise soldier(c511).csv saved
# oriental spirit(h077).csv saved
# casa sacred(h107).csv saved
# singapore sunshine(g331).csv saved
# rising from ashes(g209).csv saved
# glorified fire(d418).csv saved
# compulsory(e328).csv saved
# amazing teens(e449).csv saved
# drombeg banner(h117).csv saved
# super hong kong(d241).csv saved
# hinokami kagura(h384).csv saved
# nicetobemet(h094).csv saved
# indigenous realm(d458).csv saved
# sight hero(d487).csv saved
# perfect rock(g175).csv saved
# brave star(g268).csv saved
# dazzling fellow(g058).csv saved
# happy golf(h056).csv saved
# colourful prince(e418).csv saved
# enchanting ibis(g219).csv saved
# quorum(g005).csv saved
# charmander(g437).csv saved
# superb move(g304).csv saved
# great days(h119).csv saved
# sight success(d375).csv saved
# mayhem(h226).csv saved
# howdeepisyourlove(h093).csv saved
# blissful life(g079).csv saved
# world famous(c288).csv saved
# scholarly king(h096).csv saved
# winning delago(e289).csv saved
# super king(g300).csv saved
# lucky diamond(d446).csv saved
# adefill(g317).csv saved
# texas moon(g073).csv saved
# man star(d429).csv saved
# splendid feeling(h190).csv saved
# beauty moments(h020).csv saved
# pleasant endeavor(e114).csv saved
# beluga(d105).csv saved
# kung fu tea(c136).csv saved
# leslie(e471).csv saved
# ka ying star(c198).csv saved
# beauty inspire(h064).csv saved
# happy tango(d075).csv saved
# drops of god(e260).csv saved
# superb daddy(d235).csv saved
# harmony and rich(d110).csv saved
# ragnarr(h297).csv saved
# super elite(h247).csv saved
# maldives(d329).csv saved
# diamond diamond(h189).csv saved
# geoglyph(h812).csv saved
# snowalot(e397).csv saved
# win win fighter(e347).csv saved
# prognosis(h820).csv saved
# noble boyz(e156).csv saved
# light of wanshi(e009).csv saved
# mendocino(h814).csv saved
# never too soon(e434).csv saved
# dragon admiral(g311).csv saved
# master tornado(g410).csv saved
# youthful deal(g340).csv saved
# fire ball(d087).csv saved
# alloy king(d287).csv saved
# atomic beauty(h066).csv saved
# glorious lover(d191).csv saved
# ninja derby(h339).csv saved
# sure win win(d407).csv saved
# regency happy star(h248).csv saved
# happy trio(g244).csv saved
# jazz club(g285).csv saved
# mr majestic(g145).csv saved
# super axiom(e105).csv saved
# beat hollow(g414).csv saved
# nervous witness(e421).csv saved
# viva mama(d408).csv saved
# joyful prosperity(h213).csv saved
# turf brilliant(c456).csv saved
# speed fay fay(d121).csv saved
# blue marlin(h078).csv saved
# skyey supreme(c293).csv saved
# rattan kingdom(g035).csv saved
# master montaro(e142).csv saved
# moeraki(d084).csv saved
# wonder years(g001).csv saved
# like that(d328).csv saved
# go go sixteen(e244).csv saved
# perfect to great(d327).csv saved
# happy bear(h238).csv saved
# victor the winner(g404).csv saved
# senor toba(g103).csv saved
# just great two(g174).csv saved
# smart future(g257).csv saved
# ping hai galaxy(c377).csv saved
# fingers crossed(g403).csv saved
# copartner elites(g132).csv saved
# beau gosse(g389).csv saved
# all for st paul's(c517).csv saved
# beauty fit(e279).csv saved
# soaring tower(d500).csv saved
# split of a second(b027).csv saved
# packing goodsing(h005).csv saved
# chiron(e151).csv saved
# miraculous honour(g114).csv saved
# ka ying warrior(h028).csv saved
# publicist(h052).csv saved
# vukan(e095).csv saved
# smart fighter(h278).csv saved
# more than this(c199).csv saved
# we the south(d149).csv saved
# nothing impossible(g069).csv saved
# reve parisien(e335).csv saved
# splendid living(e192).csv saved
# brave and bold(h275).csv saved
# kurpany(d172).csv saved
# armour eagle(g093).csv saved
# alacrity(h210).csv saved
# tronic mighty(e210).csv saved
# one heart one(h004).csv saved
# call me lu(e404).csv saved
# all beauty(e355).csv saved
# act of faith(h082).csv saved
# island golden(h018).csv saved
# brave power(d153).csv saved
# millennium falcon(d281).csv saved
# aguri(h823).csv saved
# killer instinct(g020).csv saved
# best for you(c223).csv saved
# courier wonder(d449).csv saved
# super highway(g050).csv saved
# golden empire(e490).csv saved
# polymer glorious(e250).csv saved
# starship eighty(h022).csv saved
# soo fresh(h031).csv saved
# waikuku(c150).csv saved
# circuit booming(e485).csv saved
# natural storm(c461).csv saved
# amazing rocky(d356).csv saved
# alcari(a354).csv saved
# beauty joy(e058).csv saved
# master hero(d501).csv saved
# oversubscribed(c361).csv saved
# grateful heart(d278).csv saved
# fortune president(g054).csv saved
# hurry hurry rich(h130).csv saved
# g one excellent(e359).csv saved
# kyrus unicorn(d267).csv saved
# super oasis(d085).csv saved
# legion of merit(d419).csv saved
# super vince(g363).csv saved
# joy for you(h270).csv saved
# gendarme(h801).csv saved
# emerging(g296).csv saved
# winning icey(g246).csv saved
# colourful emperor(h167).csv saved
# intrepid winner(g144).csv saved
# mr ascendency(g227).csv saved
# happy united(h208).csv saved
# solid shalaa(h228).csv saved
# forever glorious(g229).csv saved
# maximus(d456).csv saved
# passing fashion(e122).csv saved
# california spangle(e314).csv saved
# fortune turbo(g316).csv saved
# function patch(e446).csv saved
# amazing boy(d513).csv saved
# ching(g380).csv saved
# double show(g250).csv saved
# five g patch(g286).csv saved
# packing hurricane(h137).csv saved
# ka ying spirit(e217).csv saved
# super win dragon(e253).csv saved
# high cloud(g351).csv saved
# escape route(e273).csv saved
# starry night(g253).csv saved
# hoodabutta(g366).csv saved
# super mission(d262).csv saved
# kowloon great(e476).csv saved
# helene feeling(h215).csv saved
# courageous knight(e163).csv saved
# magic traveller(h102).csv saved
# proud dragon(e352).csv saved
# champion instinct(h012).csv saved
# rocket spade(g170).csv saved
# leisure and gold(e093).csv saved
# serangoon(h296).csv saved
# seatosky(g284).csv saved
# c p brave(e306).csv saved
# treasure of field(e288).csv saved
# charity bingo(h254).csv saved
# nordic combined(g015).csv saved
# charity grace(e090).csv saved
# brilliant life(e396).csv saved
# management folks(e496).csv saved
# baron zee(g077).csv saved
# solid impact(e447).csv saved
# untold riches(d414).csv saved
# euro rocks(h153).csv saved
# chiu chow brother(e188).csv saved
# botanik(h815).csv saved
# chancheng prince(d270).csv saved
# ever laugh(a278).csv saved
# new asia advance(e367).csv saved
# telecom spirit(g310).csv saved
# majestic victory(e441).csv saved
# lucky archangel(e385).csv saved
# kai xin dragon(e174).csv saved
# circuit stellar(g076).csv saved
# ace talent(h046).csv saved
# aca power(e144).csv saved
# super buddy(e205).csv saved
# thunderstrike(e261).csv saved
# green laser(e409).csv saved
# surrealism(c285).csv saved
# daily trophy(h283).csv saved
# speedstar(g181).csv saved
# glorious starlight(g273).csv saved
# turbo power(e270).csv saved
# silver express(e131).csv saved
# amazing travis(h132).csv saved
# fighting star(e255).csv saved
# common room(e453).csv saved
# multisuper(g416).csv saved
# hk dragon(e222).csv saved
# lim's kosciuszko(h803).csv saved
# flaming rabbit(h257).csv saved
# mighty giant(c470).csv saved
# schnell meister(h805).csv saved
# equaletta blitz(d385).csv saved
# quantum patch(h166).csv saved
# spicy skewer(g202).csv saved
# felix the king(e340).csv saved
# moonluck(e079).csv saved
# lamma honor(e345).csv saved
# ka ying master(c240).csv saved
# more rice(h271).csv saved
# this is charisma(d102).csv saved
# bulb dragon(g442).csv saved
# i give(h036).csv saved
# hava nageela(h114).csv saved
# joy master(b222).csv saved
# smart beauty(g477).csv saved
# man light(h272).csv saved
# pachisi(h104).csv saved
# miracle victory(e325).csv saved
# astrologer(g102).csv saved
# waka waka(h217).csv saved
# the rock(d187).csv saved
# above(b345).csv saved
# happily friends(c533).csv saved
# smiling collector(g128).csv saved
# beato(h090).csv saved
# shinkansen(h277).csv saved
# midori beauty(g334).csv saved
# exuberant(e282).csv saved
# horsesain bolt(d061).csv saved
# seasons bliss(e146).csv saved
# universal crown(d240).csv saved
# chill chibi(h109).csv saved
# sky field(d216).csv saved
# universal pursuit(h286).csv saved
# fantastic treasure(e269).csv saved
# master agility(g385).csv saved
# tactical command(h197).csv saved
# harmony n home(c531).csv saved
# i can(h381).csv saved
# great brilliant(g287).csv saved
# keen unity(g298).csv saved
# flying season(g157).csv saved
# bulb pals(d095).csv saved
# tempest express(d426).csv saved
# savaquin(d479).csv saved
# super dobbin(d352).csv saved
# romantic laos(g476).csv saved
# perfetto(g198).csv saved
# happy for all(h181).csv saved
# taj dragon(h164).csv saved
# daily beauty(d070).csv saved
# supreme lucky(g457).csv saved
# russian emperor(e198).csv saved
# this is guts(e031).csv saved
# yee cheong brave(e501).csv saved
# the runner(d042).csv saved
# seizing the moment(e444).csv saved
# so we joy(d082).csv saved
# zacian(e078).csv saved
# super sunny sing(g319).csv saved
# keep you warm(d272).csv saved
# handsome guys(g044).csv saved
# rubylot(h412).csv saved
# commanding missile(g210).csv saved
# d star(g374).csv saved
# capital legend(g333).csv saved
# happy fat cat(g166).csv saved
# nishikado(h172).csv saved
# classic moon(e439).csv saved
# magic toronado(h067).csv saved
# easy snip(g211).csv saved
# imperial magee(e460).csv saved
# ezra(c056).csv saved
# tomodachi kokoroe(h303).csv saved
# chater pins(e057).csv saved
# hardly swears(c025).csv saved
# jumbo fortune(g195).csv saved
# turquoise alpha(e197).csv saved
# medic elite(g129).csv saved
# good buddy(e097).csv saved
# turtle again(h083).csv saved
# moon peaks(c403).csv saved
# packing bole(h246).csv saved
# ruby sailing(h347).csv saved
# cosmo navigator(h156).csv saved
# big two(e310).csv saved
# charizard(b463).csv saved
# celestial power(d393).csv saved
# denfield(g471).csv saved
# octoconnect(g056).csv saved
# mr fun(h010).csv saved
# loyal ambition(e489).csv saved
# lucky eternity(g478).csv saved
# concerto(e176).csv saved
# midas touch(h284).csv saved
# dragon star(h128).csv saved
# glory vase(d813).csv saved
# wood on fire(c460).csv saved
# scotch tycoon(g088).csv saved
# so you trust(g441).csv saved
# super bonus(h259).csv saved
# baby crystal(h081).csv saved
# red brick fighter(c304).csv saved
# cotton fingers(h398).csv saved
# satirical glory(h073).csv saved
# diamond star(d017).csv saved
# my oberon(h819).csv saved
# master of luck(g276).csv saved
# hero star(d033).csv saved
# super commander(d350).csv saved
# lucky sweynesse(g180).csv saved
# victory park(g197).csv saved
# asian one(e400).csv saved
# mighty star(g117).csv saved
# super ace(g387).csv saved
# juneau flash(h084).csv saved
# palace pal(g172).csv saved
# jolly forever(d331).csv saved
# smokey bear(e126).csv saved
# affirm(h306).csv saved
# tourbillon diamond(e054).csv saved
# excellent peers(g033).csv saved
# a americ te specso(h037).csv saved
# inspiring city(g267).csv saved
# gallant hero(e480).csv saved
# loriz(c036).csv saved
# forever friends(g305).csv saved
# faulds(g153).csv saved
# rattan world(g384).csv saved
# lotus favorites(e026).csv saved
# bulb prince(g179).csv saved
# pride of eight(g239).csv saved
# majestic knight(g258).csv saved
# lucky eight(g204).csv saved
# dr winning(g053).csv saved
# perfect maryknoll(e319).csv saved
# silver hammer(h112).csv saved
# valiant elegance(d285).csv saved
# dancing code(g365).csv saved
# amazing news(e123).csv saved
# dynamic spirit(g294).csv saved
# tier goody(h042).csv saved
# royal pride(e351).csv saved
# m m johnny(d115).csv saved
# classic unicorn(c343).csv saved
# blustitch(g290).csv saved
# mighty armour(h071).csv saved
# cool blue(h011).csv saved
# curling speed(h015).csv saved
# watch buddy(h185).csv saved
# self improvement(h337).csv saved
# turin redsun(g134).csv saved
# son pak fu(g265).csv saved
# captain win(e466).csv saved
# fortune master(d371).csv saved
# uptrend(h025).csv saved
# golden mission(c106).csv saved
# stoicism(e223).csv saved
# round the globe(h146).csv saved
# faithful champion(h014).csv saved
# little player(e066).csv saved
# helios express(h302).csv saved
# jack win(g155).csv saved
# excellent proposal(d386).csv saved
# copartner ambition(e218).csv saved
# beautyverse(h075).csv saved
# august moon(d409).csv saved
# my intelligent(g031).csv saved
# beauty glory(e459).csv saved
# sweet encounter(g426).csv saved
# total power(d138).csv saved
# joyful win(d451).csv saved
# joyful friendship(h295).csv saved
# nicholson returns(e452).csv saved
# the best hero(d314).csv saved
# compassion spirit(d167).csv saved
# beauty eternal(h008).csv saved
# happy mission(h050).csv saved
# lucky ruby(d338).csv saved
# highly proactive(c458).csv saved
# master of fortune(g474).csv saved
# golden samurai(h024).csv saved
# flying sword(c463).csv saved
# summit cheers(e221).csv saved
# blastoise(c450).csv saved
# unpresuming(h143).csv saved
# beauty live(g057).csv saved
# golden four(b225).csv saved
# good news(e374).csv saved
# fortune carrier(e187).csv saved
# plentiful(g400).csv saved
# endeared(h161).csv saved
# precision goal(h016).csv saved
# all are mine(h293).csv saved
# buzzinga(g240).csv saved
# ballistic man(g091).csv saved
# handsome rebel(b469).csv saved
# methane(c469).csv saved
# dragon's luck(h060).csv saved
# the irishman(g082).csv saved
# happy daily(e294).csv saved
# can't go wong(h087).csv saved
# seize the dream(g379).csv saved
# california voce(h258).csv saved
# golden express(h086).csv saved
# go ballistic(c493).csv saved
# flying bonus(b433).csv saved
# enterprise attack(h340).csv saved
# so awesome(d258).csv saved
# ice legend(e075).csv saved
# dashing genius(g064).csv saved
# top top tea(h048).csv saved
# a pal(g393).csv saved
# aegon(h818).csv saved
# majestic colour(h124).csv saved
# tailor made(c522).csv saved
# cordyceps one(e107).csv saved
# nextmodel(d015).csv saved
# above all(d397).csv saved
# boom alliance(g220).csv saved
# ka ying victory(h287).csv saved
# steel win(e111).csv saved
# one voice(g274).csv saved
# star of yiu cheung(h824).csv saved
# master delight(e463).csv saved
# iron will(g386).csv saved
# packing award(e264).csv saved
# the hulk(c431).csv saved
# magic phoenix(e440).csv saved
# jiangxi stamina(d051).csv saved
# solar winds(g154).csv saved
# billionaire secret(g303).csv saved
# united warriors(h183).csv saved
# baby(c271).csv saved
# right honourable(a164).csv saved
# heroic master(g394).csv saved
# naboo legend(g357).csv saved
# kasa papa(g312).csv saved
# big me(g348).csv saved
# fun together(h041).csv saved
# circuit seven(d474).csv saved
# marvel dragon(d111).csv saved
# smiling moon(g281).csv saved
# moonlight vista(g238).csv saved
# go go go(h196).csv saved
# free foal(e065).csv saved
# cape breton(h051).csv saved
# e universe(h151).csv saved
# awesome treasure(e435).csv saved
# stand up(g318).csv saved
# happy together(g446).csv saved
# beauty destiny(h281).csv saved
# vamos(g004).csv saved
# eason(g061).csv saved
# notorious king(h174).csv saved
# huge win(h021).csv saved
# lightning bolt(g130).csv saved
# el jefe(c466).csv saved
# toycoon(d203).csv saved
# secret vision(g302).csv saved
# kungfumaster panda(c153).csv saved
# forte(d498).csv saved
# v chevaliers(c358).csv saved
# brave dreams(g156).csv saved
# run run good(d310).csv saved
# fortune triple(d274).csv saved
# casa cosmo(g436).csv saved
# magniac(h141).csv saved
# super football(d465).csv saved
# royal agility(d349).csv saved
# infinite power(d014).csv saved
# up and up(h163).csv saved
# winning dreamer(d358).csv saved
# young sparkle(g066).csv saved
# happy horse(h061).csv saved
# sweet briar(h044).csv saved
# gold comet(d306).csv saved
# allgreektome(h007).csv saved
# rockpaperscissors(g216).csv saved
# victory moments(h142).csv saved
# lucky gold(g112).csv saved
# voyage bubble(e436).csv saved
# ho ho junior(g127).csv saved
# courier marvel(h103).csv saved
# everyone's victory(e177).csv saved
# fallon(h219).csv saved
# bravehearts(h389).csv saved
# bright kid(c060).csv saved
# private rocket(c367).csv saved
# hoss(h055).csv saved
# show respect(h138).csv saved
# peak to peak(d472).csv saved
# red majesty(e028).csv saved
# winning dragon(e461).csv saved
# ivy league(h116).csv saved
# you'remyeverything(e413).csv saved
# grand power(e017).csv saved
# viva chaleur(g368).csv saved
# young life forever(g308).csv saved
# igniting(d481).csv saved
# simply maverick(h346).csv saved
# lucky banner(g354).csv saved
# smiling time(e235).csv saved
# geraldina(h821).csv saved
# u w brother(c389).csv saved
# flying silver(e478).csv saved
# ode to joy(e228).csv saved
# decrypt(d129).csv saved
# cheong fat(h058).csv saved
# kilindini(e236).csv saved
# parterre(e234).csv saved
# tianchi monster(b350).csv saved
# young brilliant(h135).csv saved
# eighteen palms(h033).csv saved
# gummy gummy(h089).csv saved
# happy land(e353).csv saved
# lei papale(g812).csv saved
# fortune patrol(a245).csv saved
# polaris winner(g167).csv saved
# ernest feeling(e209).csv saved
# voyage star(c098).csv saved
# cordyceps six(e363).csv saved
# dinosaur boy(g473).csv saved
# the concentration(h465).csv saved
# king's capital(e077).csv saved
# inno tech winner(g419).csv saved
# comet splendido(g071).csv saved
# greenwich(h328).csv saved
# divine shining(g373).csv saved
# turin warrior(g150).csv saved
# en pointe(g009).csv saved
# winning heart(h065).csv saved
# young victory(d399).csv saved
# camino(h231).csv saved
# always fluke(h252).csv saved
# sauvestre(e315).csv saved
# starfire gems(g453).csv saved
# gorgeous vitality(g051).csv saved
# country boy(d348).csv saved
# iron king(c133).csv saved
# ima single man(d476).csv saved
# star of glory(e316).csv saved
# apex top(d136).csv saved
# king of the court(e384).csv saved
# the golden scenery(e379).csv saved
# sky gem(c251).csv saved
# raging blaze(e258).csv saved
# team goodluck(e268).csv saved
# blazing sun(e484).csv saved
# dream pursuer(g241).csv saved
# smart idea(e344).csv saved
# copartner era(c534).csv saved
# merchant prince(h268).csv saved
# harry's hero(h332).csv saved
# flamingo trillion(h192).csv saved
# plenty plenty(g344).csv saved
# flaming rib(h822).csv saved
# sea monarch(d063).csv saved
# savvy delight(e386).csv saved
# robot warrior(c532).csv saved
# circuit splendor(e482).csv saved
# fabulous eight(b473).csv saved
# the jolly(e263).csv saved
# angels hunter(g193).csv saved
# multimore(d443).csv saved
# winning steed(d155).csv saved
# speedy smartie(h108).csv saved
# romantic combo(d271).csv saved
# magic supreme(d144).csv saved
# lifeline vision(e318).csv saved
# hit the shot(e349).csv saved
# owners' star(b427).csv saved
# flaming eagle(g108).csv saved
# special m(e271).csv saved
# right as rain(g037).csv saved
# vantastic choice(g401).csv saved
# forerunner(g465).csv saved
# speedy mouse(e046).csv saved
# copartner pudong(h313).csv saved
# young horizon(g272).csv saved
# happy sharing(g169).csv saved
# california concord(d067).csv saved
# bell of victory(g116).csv saved
# atullibigeal(g173).csv saved
# thunderboltaurus(g184).csv saved
# incanto prepared(d009).csv saved
# star contact(e472).csv saved
# super fast dragon(g456).csv saved
# happy angel(g133).csv saved
# cheval valiant(e336).csv saved
# fortune warrior(h229).csv saved
# jazz with dragon(h013).csv saved
# valhalla(e495).csv saved
# northern beaches(h266).csv saved
# super hornet(g043).csv saved
# e rainbow(g314).csv saved
# super magic(h001).csv saved
# miracle beams(h218).csv saved
# speed force(c535).csv saved
# joyful genius(e388).csv saved
# sugar sugar(g016).csv saved
# tattenham(h121).csv saved
# bubble gift(h813).csv saved
# harmony n blessed(e061).csv saved
# ace one(g196).csv saved
# towards success(e036).csv saved
# all joyful(d364).csv saved
# noble ace(g418).csv saved
# happy hero(g322).csv saved
# regency master(d225).csv saved
# daring pursuit(g424).csv saved
# all is good(g269).csv saved
# mr valiant(g288).csv saved
# call me mighty(g464).csv saved
# blissful star(e168).csv saved
# california ten(e045).csv saved
# looking cool(g151).csv saved
# california forest(e475).csv saved
# chevalier prince(d298).csv saved
# arthur's kingdom(e194).csv saved
# duke wai(c188).csv saved
# smiling face(d192).csv saved
# island surprise(e429).csv saved
# strathpeffer(h095).csv saved
# bell of happiness(g178).csv saved
# butterfield(c462).csv saved
# jack d'or(h810).csv saved
# lucky planet(h235).csv saved
# success fighter(g080).csv saved
# go for tea(g040).csv saved
# ready to win(e422).csv saved
# har har at heart(h035).csv saved
# the anomaly(e113).csv saved
# dream catcher(g200).csv saved
# beauty missile(h123).csv saved
# classic archi(g295).csv saved
# gang of brothers(g046).csv saved
# lady first(b013).csv saved
# street conqueror(h341).csv saved
# classic posh(c327).csv saved
# encountered(g236).csv saved
# trust me(c134).csv saved
# adios(g338).csv saved
# elon(e272).csv saved
# shadow runner(d463).csv saved
# sparkling dolphin(c332).csv saved
# running ahead(g313).csv saved
# winning steps(g420).csv saved
# flying on the turf(c477).csv saved
# chancheng glory(h212).csv saved
# superbella(d128).csv saved
# rise brethren(g075).csv saved
# true legend(d047).csv saved
# h z tourbillon(e149).csv saved
# hero icon(g422).csv saved
# all is ready(g042).csv saved
# m m nebula(g279).csv saved
# super winner(c341).csv saved
# sure joyful(g125).csv saved
# amazing innovator(g163).csv saved
# choicerus(h029).csv saved
# hyper dragon ball(g450).csv saved
# oscar glory(e109).csv saved
# same to you(h057).csv saved
# beauty mission(g098).csv saved
# lord thunder(e390).csv saved
# cigar buddies(d299).csv saved
# pretty queen prawn(e389).csv saved
# circuit nine(g140).csv saved
# jolly honour(c080).csv saved
# dinkum(g409).csv saved
# copartner fionn(g256).csv saved
# setanta(g095).csv saved
# shining fortune(g252).csv saved
# nice birdie(g470).csv saved
# on excel star(c356).csv saved
# sweet diamond(g063).csv saved
# pakistan friend(b370).csv saved
# king land(g141).csv saved
# ultra express(d161).csv saved
# master of all(h177).csv saved
# divine era(d507).csv saved
# chiu chow spirit(h175).csv saved
# gold sterling(h032).csv saved
# fiery flying(g090).csv saved
# winning data(h230).csv saved
# easy two(g423).csv saved
# kaholo angel(h216).csv saved
# red leader(h098).csv saved
# spirited express(g356).csv saved
# get the monies(g168).csv saved
# flying mighty(d423).csv saved
# roman turbo(e043).csv saved
# baebae tsoi(e116).csv saved
# blotting paper(d043).csv saved
# savvy kingman(d416).csv saved
# hong kong hall(g315).csv saved
# packing knockhill(h255).csv saved
# champion dragon(g070).csv saved
# casa legend(g126).csv saved
# carroll street(d489).csv saved
# viva hunter(e369).csv saved
# prince of bon bon(d383).csv saved
# sparkling knight(c201).csv saved
# star ascension(g206).csv saved
# darci joy(e161).csv saved
# maximize heart(d311).csv saved
# dragon pride(d164).csv saved
# wide blue yonder(g323).csv saved
# fortune hero(d245).csv saved
# dragon fortune(e110).csv saved
# stunning impact(c366).csv saved
# samarkand(h070).csv saved
# thesis(h111).csv saved
# charming steed(e494).csv saved
# fast pace(c427).csv saved
# diamond winner(h285).csv saved
# super kingdom(e334).csv saved
# wins all(c388).csv saved
# ariel(g223).csv saved
# gallant crown(d359).csv saved
# circuit ten(g429).csv saved
# oh bravo(e037).csv saved
# lady's choice(h155).csv saved
# victory scholars(e091).csv saved
# savvy nine(d056).csv saved
# smart folks(d343).csv saved
# shenron(e284).csv saved
# panfield(e052).csv saved
# super dynamite(e199).csv saved
# prince chiswick(g388).csv saved
# dashing glory(g397).csv saved
# great for you(g186).csv saved
# universal horizon(g360).csv saved
# laws of indices(h806).csv saved
# eagle run(g415).csv saved
# swan bay(h062).csv saved
# smart leader(b456).csv saved
# green n white(h186).csv saved
# amigos giggle(e362).csv saved
# order of australia(e804).csv saved
# happihood(h261).csv saved
# oriental smoke(e467).csv saved
# bourbonaire(e365).csv saved
# yeaboi(g372).csv saved
# prince of porty(h009).csv saved
# californiadeepshot(d276).csv saved
# yellowfin(g326).csv saved
# celtic times(g230).csv saved
# beauty charge(g231).csv saved
# bulb tycoon(h129).csv saved
# lyrical motion(g081).csv saved
# diamond forever(h194).csv saved
# victorious seeker(c091).csv saved
# invincible missile(c037).csv saved
# dragon delight(g395).csv saved
# innoconstruction(g459).csv saved
# metro warrior(d387).csv saved
# happy gathering(e029).csv saved
# goodban banbanbang(g432).csv saved
# gallant waking(g165).csv saved
# sharpen bright(h276).csv saved
# star of wuyi(d503).csv saved
# straight arron(g435).csv saved
# laser victory(h176).csv saved
# run run buddy(h006).csv saved
# kasi farasi(b385).csv saved
# precise express(d198).csv saved
# dubai honour(g809).csv saved
# stone age(h817).csv saved
# shanghai dragon(b114).csv saved
# prime minister(d288).csv saved
# wellington(d176).csv saved
# go hero(h315).csv saved
# ever force(d453).csv saved
# everyone's delight(d029).csv saved
# silver sonic(h171).csv saved
# noble pursuit(h324).csv saved
# birdsville(e464).csv saved
# moduleconstruction(h127).csv saved
# yee cheong warrior(e025).csv saved
# lucky quality(d050).csv saved
# racing fighter(b285).csv saved
# accelerando(g270).csv saved
# hearty wish(e343).csv saved
# craig's master(g440).csv saved
# mission bravo(e383).csv saved
# euromissile(e277).csv saved
# keefy(g306).csv saved
# nimble nimbus(e249).csv saved
# kokushi musou(g006).csv saved
# happy matador(g243).csv saved
# telecom speed(g259).csv saved
# superb boy(g335).csv saved
# heavenly thought(c163).csv saved
# joyful hunter(h198).csv saved
# aurora hero(g024).csv saved
# compassion super(g283).csv saved
# desert star(h263).csv saved
# sakewin(g275).csv saved
# fa fa(e106).csv saved
# villa fionn(b339).csv saved
# beauty champ(g137).csv saved
# dear sibling(g336).csv saved
# gold gold baby(e220).csv saved
# round the earth(g358).csv saved
# super class(g086).csv saved
# shanghai power(d097).csv saved
# global harmony(g337).csv saved
# invincible sage(h301).csv saved
# flying ace(g045).csv saved
# bundle of charm(g213).csv saved
# rock ya heart(e380).csv saved
# helene wisdom star(d460).csv saved
# yo beauty(e275).csv saved
# let's do it(e132).csv saved
# gorytus(e302).csv saved
# pakistan zindabad(d312).csv saved
# murray's partners(b426).csv saved
# stronger(d142).csv saved
# good boy(h209).csv saved
# alloy star(d053).csv saved
# country treasure(g158).csv saved
# fantasy spring(e293).csv saved
# lightning storm(e454).csv saved

# %%
in_path = os.path.join("data","3_extracted")

entire_df = pd.DataFrame()

for file_name in [f for f in os.listdir(in_path) if not f.startswith(".")]:

    file = os.path.join(in_path, file_name)
    current_race_df = pd.read_csv(file, index_col=0)

    entire_df = pd.concat([entire_df, current_race_df])
# Out:
# /var/folders/vq/8tw_x9796214x5ztxkg8rkt80000gn/T/ipykernel_12177/2953364818.py:10: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   entire_df = pd.concat([entire_df, current_race_df])
# /var/folders/vq/8tw_x9796214x5ztxkg8rkt80000gn/T/ipykernel_12177/2953364818.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   entire_df = pd.concat([entire_df, current_race_df])
# /var/folders/vq/8tw_x9796214x5ztxkg8rkt80000gn/T/ipykernel_12177/2953364818.py:10: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   entire_df = pd.concat([entire_df, current_race_df])
# /var/folders/vq/8tw_x9796214x5ztxkg8rkt80000gn/T/ipykernel_12177/2953364818.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   entire_df = pd.concat([entire_df, current_race_df])
# /var/folders/vq/8tw_x9796214x5ztxkg8rkt80000gn/T/ipykernel_12177/2953364818.py:10: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   entire_df = pd.concat([entire_df, current_race_df])
# /var/folders/vq/8tw_x9796214x5ztxkg8rkt80000gn/T/ipykernel_12177/2953364818.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   entire_df = pd.concat([entire_df, current_race_df])
# /var/folders/vq/8tw_x9796214x5ztxkg8rkt80000gn/T/ipykernel_12177/2953364818.py:10: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   entire_df = pd.concat([entire_df, current_race_df])
# /var/folders/vq/8tw_x9796214x5ztxkg8rkt80000gn/T/ipykernel_12177/2953364818.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   entire_df = pd.concat([entire_df, current_race_df])
# /var/folders/vq/8tw_x9796214x5ztxkg8rkt80000gn/T/ipykernel_12177/2953364818.py:10: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   entire_df = pd.concat([entire_df, current_race_df])
# /var/folders/vq/8tw_x9796214x5ztxkg8rkt80000gn/T/ipykernel_12177/2953364818.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   entire_df = pd.concat([entire_df, current_race_df])
# /var/folders/vq/8tw_x9796214x5ztxkg8rkt80000gn/T/ipykernel_12177/2953364818.py:10: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   entire_df = pd.concat([entire_df, current_race_df])
# /var/folders/vq/8tw_x9796214x5ztxkg8rkt80000gn/T/ipykernel_12177/2953364818.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   entire_df = pd.concat([entire_df, current_race_df])
# /var/folders/vq/8tw_x9796214x5ztxkg8rkt80000gn/T/ipykernel_12177/2953364818.py:10: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   entire_df = pd.concat([entire_df, current_race_df])
# /var/folders/vq/8tw_x9796214x5ztxkg8rkt80000gn/T/ipykernel_12177/2953364818.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   entire_df = pd.concat([entire_df, current_race_df])
# /var/folders/vq/8tw_x9796214x5ztxkg8rkt80000gn/T/ipykernel_12177/2953364818.py:10: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   entire_df = pd.concat([entire_df, current_race_df])
# /var/folders/vq/8tw_x9796214x5ztxkg8rkt80000gn/T/ipykernel_12177/2953364818.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   entire_df = pd.concat([entire_df, current_race_df])

# %%
entire_df.to_csv(os.path.join('data','all_races.csv'))

# %%
out_path = os.path.join("data","4_races")

for race_index in entire_df['race_index'].unique():
    df = entire_df[entire_df['race_index'] == race_index]
    if len(df.index) < 5:
        continue
    df.sort_values('place', inplace=True)

    df.to_csv(os.path.join(out_path,f'{race_index}.csv'))
# Out:
# /var/folders/vq/8tw_x9796214x5ztxkg8rkt80000gn/T/ipykernel_12177/2011453047.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values('place', inplace=True)

# %%
df = pd.read_csv(os.path.join('data','all_races.csv'), index_col=0)

df = df[df['place'].notna()]

for c in df.columns:
    try:
        df[c] = df[c].astype('float32')
    except:
        pass

# %%
mean_std_dict = {}

for c in df.columns:
    if c == 'race_index':
        continue

    if df[c].dtype != 'float32':
        df[c].replace({"":np.nan}, inplace=True)
        df[c].fillna(df[c].mode().iloc[0], inplace=True)
        continue

    df[c] = pd.to_numeric(df[c], errors='coerce')

    mean = df[c].mean()
    std = df[c].std()

    df[c] = df[c].replace(np.nan, mean)
    
    mean_std_dict[c] = {'mean': mean, 'std': std}

mean_std_df = pd.DataFrame(mean_std_dict)
mean_std_df.to_csv(os.path.join('data', 'mean_std.csv'))

df.to_csv('data/all_races_cleaned.csv')

# %%
for c in df.columns:
    print(c, df[c].isna().any())
# Out:
# race_index False
# race_date False
# total_stakes False
# horse_name False
# horse_weight False
# horse_handicap False
# horse_odds False
# horse_rating False
# horse_import_type False
# horse_sex False
# horse_colour False
# horse_age False
# horse_origin False
# horse_gear False
# days_since_import False
# draw False
# jockey_age False
# jockey_nationality False
# jockey_wins False
# jockey_rides False
# jockey_stakes False
# jockey_same_race_wins False
# race_location False
# race_class False
# race_going False
# race_distance False
# race_surface False
# race_course False
# finish_time False
# place False
